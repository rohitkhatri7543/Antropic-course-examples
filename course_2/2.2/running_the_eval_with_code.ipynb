# %%
# !python --version
# Out:
# Python 3.13.12

# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (0.96.0)
# Requirement already satisfied: python-dotenv in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from anthropic) (2.13.3)
# Requirement already satisfied: sniffio in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->anthropic) (3.13)
# Requirement already satisfied: certifi in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/rohitkhatri/Antropic-course-examples/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()

# avoid warnings for old claude model use
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Initialize Antropic Chat client
from anthropic import Anthropic
client = Anthropic()

# %%
# Helper Chat Functions


## Function to Append User messasge
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


## Function to Append Assistant messasge
def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


## Main Function for chat
def get_response(messages, stop_sequences=None, system=None):

    model = "claude-haiku-4-5"  # you can change the model according to your usecase
    params = {
        "model": model,
        "max_tokens": 6000,
        "messages": messages,
    }
    if system:
        params["system"] = system    
    if stop_sequences:
        params["stop_sequences"] = stop_sequences
    message = client.messages.create(**params)
    return message


def get_chat_content(message):
    return message.content[0].text

# %%
def getStructureOutput(mesg, data_prefix="```json", stop_sequences=None):
    messages = []

    # User's request > what user wants in specific format
    add_user_message(messages, mesg)

    # start the content and make the AI generate the remaining part.
    add_assistant_message(messages, data_prefix)

    response = get_response(messages=messages, stop_sequences=stop_sequences)
    return get_chat_content(response)

# %%
import json  # For json format validation
import re    # For regex format validation
import ast   # For python syntax validation

def validate_json(data):
    try:
        json.loads(data.strip())
        return 10
    except json.JSONDecodeError: return 0

def validate_python(code):
    try:
        ast.parse(code.strip())
        return 10
    except: return 0 

def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except: return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
import json
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    
    eval_text = getStructureOutput(eval_prompt ,stop_sequences=['```'])
    print(eval_text)
    return json.loads(eval_text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    output = getStructureOutput(
        prompt,
        data_prefix="```code",  # a little cheat code to cover all the formats
        stop_sequences=["```"],
    )
    return output


def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]
    strengths = model_grade["strengths"]
    weaknesses = model_grade["weaknesses"]

    syntax_score = grade_syntax(output, test_case)
    score = (syntax_score + model_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "weaknesses": weaknesses,
        "strengths": strengths,
        "reasoning": reasoning,
    }


from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
import json

with open("./json_db/dataset_with_format.json","r") as db:
    results = run_eval(json.load(db))
# Out:
# {
#     "strengths": [
#         "Clean and concise implementation that correctly uses boto3's list_buckets() API",
#         "Proper use of list comprehension to extract bucket names from the response",
#         "Straightforward function that solves the stated requirement"
#     ],
#     "weaknesses": [
#         "Missing error handling for AWS API failures (e.g., permission denied, service unavailable)",
#         "No documentation or type hints to clarify input/output expectations",
#         "Creates a new S3 client on each function call; should accept client as parameter or use dependency injection for better testability and resource efficiency"
#     ],
#     "reasoning": "The solution correctly implements the core functionality using boto3's list_buckets() method. However, it lacks production-ready features such as error handling, type annotations, and follows suboptimal patterns for client management. The code would fail ungracefully if AWS permissions are insufficient or if the API call fails. Adding try-except blocks, type hints, and accepting an optional s3_client parameter would significantly improve robustness and testability.",
#     "score": 6
# }
#
#
# {
#   "strengths": [
#     "Correct action specified: 's3:GetObject' (singular) is the proper AWS action name, not the plural form mentioned in the task",
#     "Proper Resource ARN format: Uses correct bucket ARN with wildcard (arn:aws:s3:::my-app-data/*) to allow object access",
#     "Valid policy structure: Includes required fields (Version, Statement, Effect, Action, Resource) with correct syntax"
#   ],
#   "weaknesses": [
#     "Missing bucket-level permissions: Does not include 's3:ListBucket' permission, which is typically required to list objects in the bucket alongside GetObject",
#     "No clarification on scope: Policy allows access to all objects in the bucket without restricting by prefix, object name, or other conditions that might be desired for least-privilege"
#   ],
#   "reasoning": "The solution correctly implements the core requirement of allowing GetObject access to the specified bucket with proper ARN formatting. The action name is accurate despite the task's plural wording. However, the policy is incomplete for practical use cases—most S3 access patterns require both GetObject and ListBucket permissions. The policy could also benefit from additional conditions or resource restrictions depending on the application's actual needs.",
#   "score": 7
# }
#
#
# {
#     "strengths": [
#         "Correctly matches 12-digit sequences using \\d{12}",
#         "Uses word boundaries (\\b) to avoid partial matches within longer number sequences",
#         "Simple and readable pattern"
#     ],
#     "weaknesses": [
#         "Not ARN-specific: will match any 12-digit number in any context, not just Account IDs in ARNs",
#         "Missing ARN structure validation: should anchor to ARN format (e.g., arn:aws:...:ACCOUNT_ID:...) to ensure extracted number is actually in the Account ID position",
#         "No validation that the number appears between colons, which is the actual ARN structure requirement"
#     ],
#     "reasoning": "While the regex technically extracts 12-digit numbers, it lacks specificity for AWS ARNs. A better solution would incorporate ARN structure context, such as matching within the colon-delimited format. For example: `arn:aws:[^:]+:[^:]*:(\\d{12}):` would ensure the 12-digit number is in the actual Account ID position of an ARN. The current pattern could produce false positives when processing text containing unrelated 12-digit numbers.",
#     "score": 5
# }
#
# Average score: 8.0

# %%
# With less temprature we will likely get the almost same responses each time

print(json.dumps(results,indent=2))
# Out:
# [
#   {
#     "output": "\nimport boto3\n\ndef get_all_s3_bucket_names():\n    s3_client = boto3.client('s3')\n    response = s3_client.list_buckets()\n    bucket_names = [bucket['Name'] for bucket in response['Buckets']]\n    return bucket_names\n",
#     "test_case": {
#       "task": "Write a Python function using boto3 to return a list of all S3 bucket names in an account.",
#       "format": "python"
#     },
#     "score": 8.0,
#     "weaknesses": [
#       "Missing error handling for AWS API failures (e.g., permission denied, service unavailable)",
#       "No documentation or type hints to clarify input/output expectations",
#       "Creates a new S3 client on each function call; should accept client as parameter or use dependency injection for better testability and resource efficiency"
#     ],
#     "strengths": [
#       "Clean and concise implementation that correctly uses boto3's list_buckets() API",
#       "Proper use of list comprehension to extract bucket names from the response",
#       "Straightforward function that solves the stated requirement"
#     ],
#     "reasoning": "The solution correctly implements the core functionality using boto3's list_buckets() method. However, it lacks production-ready features such as error handling, type annotations, and follows suboptimal patterns for client management. The code would fail ungracefully if AWS permissions are insufficient or if the API call fails. Adding try-except blocks, type hints, and accepting an optional s3_client parameter would significantly improve robustness and testability."
#   },
#   {
#     "output": "\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": \"s3:GetObject\",\n      \"Resource\": \"arn:aws:s3:::my-app-data/*\"\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create an IAM Policy (JSON) that allows 's3:GetObjects' access but only for a bucket named 'my-app-data'.",
#       "format": "json"
#     },
#     "score": 8.5,
#     "weaknesses": [
#       "Missing bucket-level permissions: Does not include 's3:ListBucket' permission, which is typically required to list objects in the bucket alongside GetObject",
#       "No clarification on scope: Policy allows access to all objects in the bucket without restricting by prefix, object name, or other conditions that might be desired for least-privilege"
#     ],
#     "strengths": [
#       "Correct action specified: 's3:GetObject' (singular) is the proper AWS action name, not the plural form mentioned in the task",
#       "Proper Resource ARN format: Uses correct bucket ARN with wildcard (arn:aws:s3:::my-app-data/*) to allow object access",
#       "Valid policy structure: Includes required fields (Version, Statement, Effect, Action, Resource) with correct syntax"
#     ],
#     "reasoning": "The solution correctly implements the core requirement of allowing GetObject access to the specified bucket with proper ARN formatting. The action name is accurate despite the task's plural wording. However, the policy is incomplete for practical use cases\u2014most S3 access patterns require both GetObject and ListBucket permissions. The policy could also benefit from additional conditions or resource restrictions depending on the application's actual needs."
#   },
#   {
#     "output": "\n\\b\\d{12}\\b\n",
#     "test_case": {
#       "task": "Create a regex to extract the Account ID (12-digit number) from an AWS ARN string.",
#       "format": "regex"
#     },
#     "score": 7.5,
#     "weaknesses": [
#       "Not ARN-specific: will match any 12-digit number in any context, not just Account IDs in ARNs",
#       "Missing ARN structure validation: should anchor to ARN format (e.g., arn:aws:...:ACCOUNT_ID:...) to ensure extracted number is actually in the Account ID position",
#       "No validation that the number appears between colons, which is the actual ARN structure requirement"
#     ],
#     "strengths": [
#       "Correctly matches 12-digit sequences using \\d{12}",
#       "Uses word boundaries (\\b) to avoid partial matches within longer number sequences",
#       "Simple and readable pattern"
#     ],
#     "reasoning": "While the regex technically extracts 12-digit numbers, it lacks specificity for AWS ARNs. A better solution would incorporate ARN structure context, such as matching within the colon-delimited format. For example: `arn:aws:[^:]+:[^:]*:(\\d{12}):` would ensure the 12-digit number is in the actual Account ID position of an ARN. The current pattern could produce false positives when processing text containing unrelated 12-digit numbers."
#   }
# ]
